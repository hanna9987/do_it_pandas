# %% [markdown]
# # 데이터셋 불러오기

# %%
import pandas

# %%
pandas.read_csv('../data/gapminder.tsv',sep='\t')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
print(3+5)
print(4-0)
# Out:
# 8
# 4

# %%
df = pandas.read_csv('../data/gapminder.tsv',sep='\t')

# %%
print(df)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
import pandas as pd

# %%
pd.read_csv('../data/gapminder.tsv', sep='\t')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.size
# Out:
# 10224

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
print(df.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.head(2)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.tail(2
    )
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.sample()
# Out:
#          country continent  year  lifeExp      pop    gdpPercap
# 347  Congo, Rep.    Africa  2007   55.322  3800610  3632.557798

# %%
df.sample(5
        )
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 273        Chad    Africa  1997   51.573   7562011   1004.961353
# 939    Malaysia      Asia  1967   59.371  10154878   2277.742396
# 1506     Taiwan      Asia  1982   72.160  18501390   7426.354774
# 572     Germany    Europe  1992   76.070  80597764  26505.303170
# 1453  Swaziland    Africa  1957   43.424    326741   1244.708364

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_s = df['country']

# %%
type(country_s)
# Out:
# pandas.core.series.Series

# %%
country_s.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
# [] 안에는 하나만 들어가야 함.
df['country','continent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'continent')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df['country','continent']
#
# ...

# %%
df[['country','continent']]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sample(2)
# Out:
#       country continent  year  lifeExp       pop    gdpPercap
# 303  Colombia  Americas  1967   59.963  19764027  2678.729839
# 868   Lebanon      Asia  1972   65.421   2680018  7486.384341

# %%
#기본적으로 행,열이 들어감
# df.loc[행,열]

df.loc[303]
# Out:
# country         Colombia
# continent       Americas
# year                1967
# lifeExp           59.963
# pop             19764027
# gdpPercap    2678.729839
# Name: 303, dtype: object

# %%
df.loc[303,'country']
# Out:
# 'Colombia'

# %%
df.loc[303,['country','pop']]
# Out:
# country    Colombia
# pop        19764027
# Name: 303, dtype: object

# %%
df.loc[303:313,['country','pop']]
# Out:
#       country       pop
# 303  Colombia  19764027
# 304  Colombia  22542890
# 305  Colombia  25094412
# 306  Colombia  27764644
# 307  Colombia  30964245
# 308  Colombia  34202721
# 309  Colombia  37657830
# 310  Colombia  41008227
# 311  Colombia  44227550
# 312   Comoros    153936
# 313   Comoros    170928

# %%
df.loc[303:313,'country':'pop']
# Out:
#       country continent  year  lifeExp       pop
# 303  Colombia  Americas  1967   59.963  19764027
# 304  Colombia  Americas  1972   61.623  22542890
# 305  Colombia  Americas  1977   63.837  25094412
# 306  Colombia  Americas  1982   66.653  27764644
# 307  Colombia  Americas  1987   67.768  30964245
# 308  Colombia  Americas  1992   68.421  34202721
# 309  Colombia  Americas  1997   70.313  37657830
# 310  Colombia  Americas  2002   71.682  41008227
# 311  Colombia  Americas  2007   72.889  44227550
# 312   Comoros    Africa  1952   40.715    153936
# 313   Comoros    Africa  1957   42.460    170928

# %%
# df.iloc[행인덱스,열인덱스]
df.iloc[:,0:1]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
df.iloc[[1,2,3],:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[[1,2,3],-1]
# Out:
# 1    820.853030
# 2    853.100710
# 3    836.197138
# Name: gdpPercap, dtype: float64

# %%
df.head
# Out:
# <bound method NDFrame.head of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.head(15)
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
year_df = df.groupby('year')

# %%
year_df['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby(['year','continent'])['lifeExp'].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
df_multi = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()

# %%
df_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 60 entries, (1952, 'Africa') to (2007, 'Oceania')
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lifeExp    60 non-null     float64
#  1   gdpPercap  60 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3+ KB

# %%
df_flat = df_multi.reset_index()

# %%
df_flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       60 non-null     int64
#  1   continent  60 non-null     object
#  2   lifeExp    60 non-null     float64
#  3   gdpPercap  60 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df_flat.sample()
# Out:
#     year continent   lifeExp    gdpPercap
# 17  1967      Asia  54.66364  5971.173374

# %%
df_multi = df\
.groupby(['year','continent'])[['lifeExp','gdpPercap']]\
.mean()

# %%
df_multi
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df_multi = df.groupby(['year'
                       ,'continent'])[['lifeExp'
                                       ,'gdpPercap']].mean()
# ,는 그냥 줄바꿈해도 가능. 역슬래시 안써도 됌.

# %%
df_multi = df.groupby(
    ['year','continent']
)[['lifeExp','gdpPercap']].mean()
# 괄호 안에도 줄바꿈 가능.

# %%
df_multi = (df
            .groupby(['year','continent'])[['lifeExp','gdpPercap']]
            .mean()
            .reset_index()
           )
# 매서드 체이닝: 코드를 ()로 감싸 여러개 매서드 연결.

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.groupby('continent')['country'].count()
# Out:
# continent
# Africa      624
# Americas    300
# Asia        396
# Europe      360
# Oceania      24
# Name: country, dtype: int64

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby('continent')['country'].value_counts()
# Out:
# continent  country
# Africa     Algeria           12
#            Angola            12
#            Benin             12
#            Botswana          12
#            Burkina Faso      12
#                              ..
# Europe     Switzerland       12
#            Turkey            12
#            United Kingdom    12
# Oceania    Australia         12
#            New Zealand       12
# Name: count, Length: 142, dtype: int64

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
data = df.groupby(['year'])['lifeExp'].mean().plot()

# %%
data.plot(kind = 'bar')
# Out:
# []
