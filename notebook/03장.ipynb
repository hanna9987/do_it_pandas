# %% [markdown]
# # 데이터 만들기

# %%
import pandas as pd

# %%
s = pd.Series(['banana',42])

# %%
s
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
pd.Series(
    data=['wes','cos'],
    index=['p','w'])
# Out:
# p    wes
# w    cos
# dtype: object

# %%
scientists = pd.DataFrame({
        "Name": ["Rosaline Franklin", "William Gosset"],
        "Occupation": ["Chemist", "Statistician"],
        "Born": ["1920-07-25", "1876-06-13"],
        "Died": ["1958-04-16", "1937-10-16"],
        "Age": [37, 61],
})

# %%
scientists
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
scientists.columns
# Out:
# Index(['Name', 'Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %%
scientists.values
# Out:
# array([['Rosaline Franklin', 'Chemist', '1920-07-25', '1958-04-16', 37],
#        ['William Gosset', 'Statistician', '1876-06-13', '1937-10-16', 61]],
#       dtype=object)

# %%
scientists
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists['Age']
# Out:
# 0    37
# 1    61
# Name: Age, dtype: int64

# %%
scientists['Age'].mean()
# Out:
# 49.0

# %%
scientists['Age'].sort_values(ascending=False)
# 값 정렬.
# Out:
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
scientists['Age'].to_frame()
# Out:
#    Age
# 0   37
# 1   61

# %%
scientists.transpose()
# Out:
#                             0               1
# Name        Rosaline Franklin  William Gosset
# Occupation            Chemist    Statistician
# Born               1920-07-25      1876-06-13
# Died               1958-04-16      1937-10-16
# Age                        37              61

# %%
scientists.T
# scientists.transpose() 와 동일.
# Out:
#                             0               1
# Name        Rosaline Franklin  William Gosset
# Occupation            Chemist    Statistician
# Born               1920-07-25      1876-06-13
# Died               1958-04-16      1937-10-16
# Age                        37              61

# %%
sci = pd.read_csv('../data/scientists.csv')

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
sci.head(1)
# Out:
#                 Name        Born        Died  Age Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37    Chemist

# %%
sci.tail(1)
# Out:
#            Name        Born        Died  Age     Occupation
# 7  Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
sci.sample()
# Out:
#             Name        Born        Died  Age Occupation
# 4  Rachel Carson  1907-05-27  1964-04-14   56  Biologist

# %%
sci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes

# %%
sci.describe()
# Out:
#              Age
# count   8.000000
# mean   59.125000
# std    18.325918
# min    37.000000
# 25%    44.000000
# 50%    58.500000
# 75%    68.750000
# max    90.000000

# %%
sci['Age'].mean()
# Out:
# 59.125

# %%
sci['Age'] > sci['Age'].mean()
# 1,2,3,7 행의 사람이 큰 사람임.
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
sci[sci['Age'] > sci['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
ss = sci['Age'] > sci['Age'].mean()

# %%
list(ss)
# Out:
# [False, True, True, True, False, False, False, True]

# %%
sci[[False, True, True, True, False, False, False, True]]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = sci['Age']

# %%
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages + ages
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
ages + 10
# Out:
# 0     47
# 1     71
# 2    100
# 3     76
# 4     66
# 5     55
# 6     51
# 7     87
# Name: Age, dtype: int64

# %%
ages + pd.Series([1,2])
# Out:
# 0    38.0
# 1    63.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# dtype: float64

# %%
pd.Series([1,2])
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
sci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes

# %%
pd.to_datetime(sci['Born'],format='%Y-%m-%d')
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
sci['Born_dt'] = pd.to_datetime(sci['Born'],format='%Y-%m-%d')

# %%
sci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   Born_dt     8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 516.0+ bytes

# %%
pd.to_datetime(sci[['Born','Died']],format='%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 pd.to_datetime(sci[['Born','Died']],format='%Y-%m-%d')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1070, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1070     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1071 elif isinstance(arg, Index):
#    1072     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1186, in _assemble_from_unit_mappings(arg, errors, utc)
#    1184 if len(req):
#    1185     _required = ",".join(req)
# -> 1186     raise ValueError(
# ...

# %%
import pandas as pd
sci = pd.read_csv('../data/scientists.csv')

# %%
sci['Died_dt'] = pd.to_datetime(sci['Died'],format='%Y-%m-%d')

# %%
sci['Born_dt'] = pd.to_datetime(sci['Born'],format='%Y-%m-%d')

# %%
sci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   Died_dt     8 non-null      datetime64[ns]
#  6   Born_dt     8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 580.0+ bytes

# %%
sci['Age'].sample()
# Out:
# 6    41
# Name: Age, dtype: int64

# %%
sci['Age'].sample(frac=1, random_state=42)
# Out:
# 1    61
# 5    45
# 0    37
# 7    77
# 2    90
# 4    56
# 3    66
# 6    41
# Name: Age, dtype: int64

# %%
sci['Age'] = sci['Age'].sample(frac=1, random_state=42)
# 이렇게 해도 순서 안바뀜. 인덱스값은 존재하면 변하지 않기 때문.

# %%
sci['Age']
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
sci['Age'].sample(frac=1, random_state=42).values
# Out:
# array([45, 56, 61, 41, 37, 90, 77, 66], dtype=int64)

# %%
sci['Age']
# Out:
# 0    61
# 1    45
# 2    37
# 3    77
# 4    90
# 5    56
# 6    66
# 7    41
# Name: Age, dtype: int64

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt
# 0 1958-04-16 1920-07-25
# 1 1937-10-16 1876-06-13
# 2 1910-08-13 1820-05-12
# 3 1934-07-04 1867-11-07
# 4 1964-04-14 1907-05-27
# 5 1858-06-16 1813-03-15
# 6 1954-06-07 1912-06-23
# 7 1855-02-23 1777-04-30

# %%
sci['Age_days'] = sci['Died_dt']-sci['Born_dt']

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days
# 0 1958-04-16 1920-07-25 13779 days
# 1 1937-10-16 1876-06-13 22404 days
# 2 1910-08-13 1820-05-12 32964 days
# 3 1934-07-04 1867-11-07 24345 days
# 4 1964-04-14 1907-05-27 20777 days
# 5 1858-06-16 1813-03-15 16529 days
# 6 1954-06-07 1912-06-23 15324 days
# ...

# %%
sci['Age_days'].dt

# %%
type(sci['Age_days']
# 이건 시리즈라서 안됨?
# Out:
# pandas.core.series.Series

# %%
sci['Age_days'].iloc[0]
# 한개씩 데이터를 뽑아서 Timedelta 이걸로 가능?
# Out:
# Timedelta('13779 days 00:00:00')

# %%
sci['Age_days'].dt.days/365
# Out:
# 0    37.750685
# 1    61.380822
# 2    90.312329
# 3    66.698630
# 4    56.923288
# 5    45.284932
# 6    41.983562
# 7    77.868493
# Name: Age_days, dtype: float64

# %%
import numpy as np

# %%
np.floor(4.6)
# Out:
# 4.0

# %%
(sci['Age_days'].dt.days/365).apply(np.floor)
# Out:
# 0    37.0
# 1    61.0
# 2    90.0
# 3    66.0
# 4    56.0
# 5    45.0
# 6    41.0
# 7    77.0
# Name: Age_days, dtype: float64

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days
# 0 1958-04-16 1920-07-25 13779 days
# 1 1937-10-16 1876-06-13 22404 days
# 2 1910-08-13 1820-05-12 32964 days
# 3 1934-07-04 1867-11-07 24345 days
# 4 1964-04-14 1907-05-27 20777 days
# 5 1858-06-16 1813-03-15 16529 days
# 6 1954-06-07 1912-06-23 15324 days
# ...

# %%
sci['Age_years'] = (sci['Age_days'].dt.days/365).apply(np.floor)

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years
# 0 1958-04-16 1920-07-25 13779 days       37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0
# 3 1934-07-04 1867-11-07 24345 days       66.0
# 4 1964-04-14 1907-05-27 20777 days       56.0
# ...

# %%
sci.assign(
    age_days_a = sci['Died_dt']-sci['Born_dt'],
    age_years_a = (sci['Age_days'].dt.days/365).apply(np.floor)
)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# ...

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years
# 0 1958-04-16 1920-07-25 13779 days       37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0
# 3 1934-07-04 1867-11-07 24345 days       66.0
# 4 1964-04-14 1907-05-27 20777 days       56.0
# ...

# %%
sci = sci.assign(
    age_days_a = sci['Died_dt']-sci['Born_dt'],
    age_years_a = (sci['Age_days'].dt.days/365).apply(np.floor)
)

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# ...

# %%
sci.drop(['Age'],axis=1)
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# 3 1934-07-04 1867-11-07 24345 days       66.0 24345 days         66.0
# ...

# %%
sci.drop(['Age_days'],axis=1)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12       90.0 32964 days         90.0
# 3 1934-07-04 1867-11-07       66.0 24345 days         66.0
# ...

# %%
sci
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# ...

# %%
sci.drop(columns=['Age'])
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# 3 1934-07-04 1867-11-07 24345 days       66.0 24345 days         66.0
# ...

# %%
sci.to_pickle('sci.pickle')

# %%
pd.read_pickle('sci.pickle')
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# ...

# %%
sci.to_json('sci.json')

# %%
pd.read_json('sci.json')
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#          Died_dt        Born_dt       Age_days  Age_years     age_days_a  \
# 0  -369619200000 -1560124800000  1190505600000         37  1190505600000
# 1 -1016496000000 -2952201600000  1935705600000         61  1935705600000
# 2 -1874102400000 -4722192000000  2848089600000         90  2848089600000
# ...

# %%
# !pip list | grep openpyxl
# 피클 제이슨 처럼 저런 파일 형식이 있는지 확인하는 법.
# Out:
# openpyxl                          3.1.5

# %%
# !pip list | grep pyarrow
# Out:
# pyarrow                           16.1.0

# %%
sci_dict = sci.to_dict()

# %%
pd.DataFrame.from_dict(sci_dict)
# 판다스 함수에 read_json 처럼 dict은 from을 씀. 딕셔너리 형태를 DataFrame처럼 보여달라는 함수.
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   56           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   41       Mathematician
#
#      Died_dt    Born_dt   Age_days  Age_years age_days_a  age_years_a
# 0 1958-04-16 1920-07-25 13779 days       37.0 13779 days         37.0
# 1 1937-10-16 1876-06-13 22404 days       61.0 22404 days         61.0
# 2 1910-08-13 1820-05-12 32964 days       90.0 32964 days         90.0
# ...

# %%
import matplotlib.pyplot
