# %%
def my_sq(x):
    '''
    제곱해서 리턴
    '''
    return x ** 2 #**2 제곱하는거.

# %%
my_sq(2)
# Out:
# 4

# %%
def avg_2(x,y):
    '''
    두 숫자의 평균을 구하는 함수
    '''
    return (x+y)/2

# %%
avg_2(4,7)
# Out:
# 5.5

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {'a':[10,20,30],
     'b':[20,30,40]})

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df['a'] **2
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df.a.apply(my_sq)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df.apply(my_sq)
# Out:
#      a     b
# 0  100   400
# 1  400   900
# 2  900  1600

# %%
def my_sq(x):
    '''
    제곱해서 리턴
    '''
    print(x)
    return x

# %%
def avg_2(x,y):
    '''
    두 숫자의 평균을 구하는 함수
    '''
    print(x)
    print(y)
    return (x+y)/2

# %%
df.a.apply(my_sq)
# Out:
# 10
# 20
# 30
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64

# %%
df.apply(my_sq)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df.apply(avg_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.apply(avg_2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
# ...

# %%
df.apply(avg_2,y=2)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 2
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# 2
#       a     b
# 0   6.0  11.0
# 1  11.0  16.0
# 2  16.0  21.0

# %%
df.apply(avg_2,y=2,axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# 2
# a    20
# b    30
# Name: 1, dtype: int64
# 2
# a    30
# b    40
# Name: 2, dtype: int64
# 2
#       a     b
# 0   6.0  11.0
# 1  11.0  16.0
# 2  16.0  21.0

# %%
def avg_3(col):
    print(col)
    x = col[0]
    y = col[1]
    z = col[2]
    return (x+y+z)/3

# %%
df.apply(avg_3)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# a    20.0
# b    30.0
# dtype: float64

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df.apply(avg_3,axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# C:\Users\82106\AppData\Local\Temp\ipykernel_4700\2736974254.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = col[0]
# C:\Users\82106\AppData\Local\Temp\ipykernel_4700\2736974254.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = col[1]
# C:\Users\82106\AppData\Local\Temp\ipykernel_4700\2736974254.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   z = col[2]
# ...

# %%
def avg_4(col):
    print(col)
    x = col.iloc[0]
    y = col.iloc[1]
    return (x+y)/2

# %%
df.apply(avg_4,axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# a    20
# b    30
# Name: 1, dtype: int64
# a    30
# b    40
# Name: 2, dtype: int64
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
def avg_5(row):
    print(row)
    x = row.iloc[0]
    y = row.iloc[1]
    return (x+y)/2

# %%
df.apply(avg_5,axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# a    20
# b    30
# Name: 1, dtype: int64
# a    30
# b    40
# Name: 2, dtype: int64
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df[['a','b']].apply(lambda x:(x.iloc[0]+x.iloc[1])/2,axis=1)
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %% [markdown]
# # 7장 데이터 결합하기

# %%
df1 = pd.read_csv('../data/concat_1.csv')

# %%
df2 = pd.read_csv('../data/concat_2.csv')

# %%
df3 = pd.read_csv('../data/concat_3.csv')

# %%
pd.concat([df1,df2,df3])
# concat은 행 방향(열로)으로 붙이는 함수.
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
pd.Series(['n1','n2','n3','n4'])
# Out:
# 0    n1
# 1    n2
# 2    n3
# 3    n4
# dtype: object

# %%
new_s = pd.Series(['n1','n2','n3','n4'])

# %%
pd.concat([df1,new_s])
# 기본이 아우터 조인 형식.
# Out:
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4

# %%
pd.concat([df1,new_s],axis=1)
# Out:
#     A   B   C   D   0
# 0  a0  b0  c0  d0  n1
# 1  a1  b1  c1  d1  n2
# 2  a2  b2  c2  d2  n3
# 3  a3  b3  c3  d3  n4

# %%
pd.concat([df1,df2,df3],ignore_index=True)
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
from pathlib import Path

# %%
Path(".").glob('../data/billboard_by_week/billboard-*.csv')
# Out:
# <generator object Path.glob at 0x000001B66B547120>

# %%
data_files = Path(".").glob('../data/billboard_by_week/billboard-*.csv')
# list(data_files)
# 원래 뒤죽박죽 순서로 출력.
# sorted(list(data_files))
# 순서대로 출력하게 하는 내장함수.
data_files = sorted(list(data_files))

# %%
data_files
# Out:
# [WindowsPath('../data/billboard_by_week/billboard-01.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-02.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-03.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-04.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-05.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-06.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-07.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-08.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-09.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-10.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-11.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-12.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-13.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-14.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-15.csv'),
#  WindowsPath('../data/billboard_by_week/billboard-16.csv'),
# ...

# %%
pd.read_csv(data_files[0])
# Out:
#      year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk1
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk1
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk1
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk1
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk1
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %%
for filename in data_files:
    print(filename)
# Out:
# ..\data\billboard_by_week\billboard-01.csv
# ..\data\billboard_by_week\billboard-02.csv
# ..\data\billboard_by_week\billboard-03.csv
# ..\data\billboard_by_week\billboard-04.csv
# ..\data\billboard_by_week\billboard-05.csv
# ..\data\billboard_by_week\billboard-06.csv
# ..\data\billboard_by_week\billboard-07.csv
# ..\data\billboard_by_week\billboard-08.csv
# ..\data\billboard_by_week\billboard-09.csv
# ..\data\billboard_by_week\billboard-10.csv
# ..\data\billboard_by_week\billboard-11.csv
# ..\data\billboard_by_week\billboard-12.csv
# ..\data\billboard_by_week\billboard-13.csv
# ..\data\billboard_by_week\billboard-14.csv
# ..\data\billboard_by_week\billboard-15.csv
# ..\data\billboard_by_week\billboard-16.csv
# ..\data\billboard_by_week\billboard-17.csv
# ..\data\billboard_by_week\billboard-18.csv
# ..\data\billboard_by_week\billboard-19.csv
# ..\data\billboard_by_week\billboard-20.csv
# ..\data\billboard_by_week\billboard-21.csv
# ..\data\billboard_by_week\billboard-22.csv
# ...

# %%
data_files = Path(".").glob('../data/billboard_by_week/billboard-*.csv')
for filename in data_files:
    print(filename)
# Out:
# ..\data\billboard_by_week\billboard-01.csv
# ..\data\billboard_by_week\billboard-02.csv
# ..\data\billboard_by_week\billboard-03.csv
# ..\data\billboard_by_week\billboard-04.csv
# ..\data\billboard_by_week\billboard-05.csv
# ..\data\billboard_by_week\billboard-06.csv
# ..\data\billboard_by_week\billboard-07.csv
# ..\data\billboard_by_week\billboard-08.csv
# ..\data\billboard_by_week\billboard-09.csv
# ..\data\billboard_by_week\billboard-10.csv
# ..\data\billboard_by_week\billboard-11.csv
# ..\data\billboard_by_week\billboard-12.csv
# ..\data\billboard_by_week\billboard-13.csv
# ..\data\billboard_by_week\billboard-14.csv
# ..\data\billboard_by_week\billboard-15.csv
# ..\data\billboard_by_week\billboard-16.csv
# ..\data\billboard_by_week\billboard-17.csv
# ..\data\billboard_by_week\billboard-18.csv
# ..\data\billboard_by_week\billboard-19.csv
# ..\data\billboard_by_week\billboard-20.csv
# ..\data\billboard_by_week\billboard-21.csv
# ..\data\billboard_by_week\billboard-22.csv
# ...

# %%
data_files = Path(".").glob('../data/billboard_by_week/billboard-*.csv')
list_df = []
for filename in data_files:
    df = pd.read_csv(filename)
    list_df.append(df)

# %%
len(list_df)
# Out:
# 76

# %%
pd.concat(list_df)
# Out:
#      year            artist                    track  time date.entered  week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   wk1
# ..    ...               ...                      ...   ...          ...   ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk76
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk76
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk76
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk76
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk76
#
#      rating
# 0      87.0
# ...

# %%
pd.read_csv('../data/survey_person.csv')
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
pd.read_csv('../data/survey_site.csv')
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
pd.read_csv('../data/survey_survey.csv')
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
pd.read_csv('../data/survey_visited.csv')
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited['site'].value_counts()
# Out:
# site
# DR-3     4
# DR-1     3
# MSK-4    1
# Name: count, dtype: int64

# %%
person = pd.read_csv('../data/survey_person.csv')
site = pd.read_csv('../data/survey_site.csv')
survey = pd.read_csv('../data/survey_survey.csv')
visited = pd.read_csv('../data/survey_visited.csv')

# %%
visited_subset = visited.loc[[0,2,6],:]

# %%
visited.loc[[0,2,6],:]
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
pd.merge(site,visited_subset,left_on='name',right_on='site')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
pd.merge(site,visited_subset,left_on='name',right_on='site')

# %%
site.merge(visited_subset,left_on='name',right_on='site')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
site.merge(visited,left_on='name',right_on='site')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
# person.merge(survey
# 3개 병합해보기.

# %% [markdown]
# # 8장 결측값 채우기

# %%
import seaborn as sns
import numpy as np

# %%
sns.load_dataset('tips').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips = sns.load_dataset('tips')

# %%
np.random.seed(42)
tips_10 = tips.sample(10)
# tips_10 = tips.sample(10, random_state=42) 위 두줄과 같은 내용.

# %%
tips_10
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
tips_10 = tips.sample(10, random_state=42)

# %%
tips_10.loc[np.random.permutation(tips_10.index)[:4],'total_bill'] = np.NaN

# %%
tips_10
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 153         NaN  2.00    Male     No   Sun  Dinner     4
# 211         NaN  5.16    Male    Yes   Sat  Dinner     4
# 198         NaN  2.00  Female    Yes  Thur   Lunch     2
# 176         NaN  2.00    Male    Yes   Sun  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
tips_10.groupby('sex').count
#count 는 NaN값(결측값) 빼고 계산. 결측값이 얼마 있다는걸 확인할 수 있음.
# Out:
# C:\Users\82106\AppData\Local\Temp\ipykernel_4700\3588281804.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_10.groupby('sex').count()
#         total_bill  tip  smoker  day  time  size
# sex
# Male             4    7       7    7     7     7
# Female           2    3       3    3     3     3

# %%
tips_10['total_bill'].fillna(tips_10['total_bill'].mean())
# Out:
# 24     19.820000
# 6       8.770000
# 153    16.611667
# 211    16.611667
# 198    16.611667
# 176    16.611667
# 192    28.440000
# 124    12.480000
# 9      14.780000
# 101    15.380000
# Name: total_bill, dtype: float64

# %%
tips_filltered = (
    tips
    .groupby("size")
